# %% [markdown]
# # 1 - Data gathering
#
# I am going to use as the main source of info the dataset offered by IMDB in https://datasets.imdbws.com/
# Specifically, I choose the file **title.basics.tsv.gz**, which has this structure according to the documentation:
#
# * tconst (string) - alphanumeric unique identifier of the title
# * titleType (string) – the type/format of the title (e.g. movie, short, tvseries, tvepisode, video, etc)
# * primaryTitle (string) – the more popular title / the title used by the filmmakers on promotional materials at the point of release
# * originalTitle (string) - original title, in the original language
# * isAdult (boolean) - 0: non-adult title; 1: adult title
# * startYear (YYYY) – represents the release year of a title. In the case of TV Series, it is the series start year
# * endYear (YYYY) – TV Series end year. ‘\N’ for all other title types
# * runtimeMinutes – primary runtime of the title, in minutes
# * genres (string array) – includes up to three genres associated with the title

# %%
import pandas as pd

basics = pd.read_csv('data/data.tsv', sep='\t')
basics
# Out:
# C:\Users\carlo\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (4,5) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#             tconst  titleType               primaryTitle  \
# 0        tt0000001      short                 Carmencita
# 1        tt0000002      short     Le clown et ses chiens
# 2        tt0000003      short             Pauvre Pierrot
# 3        tt0000004      short                Un bon bock
# 4        tt0000005      short           Blacksmith Scene
# ...            ...        ...                        ...
# 8738245  tt9916848  tvEpisode              Episode #3.17
# 8738246  tt9916850  tvEpisode              Episode #3.19
# 8738247  tt9916852  tvEpisode              Episode #3.20
# 8738248  tt9916856      short                   The Wind
# 8738249  tt9916880  tvEpisode  Horrid Henry Knows It All
#
#                      originalTitle isAdult startYear endYear runtimeMinutes  \
# 0                       Carmencita       0      1894      \N              1
# 1           Le clown et ses chiens       0      1892      \N              5
# 2                   Pauvre Pierrot       0      1892      \N              4
# 3                      Un bon bock       0      1892      \N             12
# 4                 Blacksmith Scene       0      1893      \N              1
# ...                            ...     ...       ...     ...            ...
# 8738245              Episode #3.17       0      2010      \N             \N
# 8738246              Episode #3.19       0      2010      \N             \N
# 8738247              Episode #3.20       0      2010      \N             \N
# 8738248                   The Wind       0      2015      \N             27
# 8738249  Horrid Henry Knows It All       0      2014      \N             10
#
#                              genres
# 0                 Documentary,Short
# 1                   Animation,Short
# 2          Animation,Comedy,Romance
# 3                   Animation,Short
# 4                      Comedy,Short
# ...                             ...
# 8738245         Action,Drama,Family
# 8738246         Action,Drama,Family
# 8738247         Action,Drama,Family
# 8738248                       Short
# 8738249  Adventure,Animation,Comedy
#
# [8738250 rows x 9 columns]

# %%
basics.titleType.value_counts(dropna=False)
# Out:
# tvEpisode       6541970
# short            858445
# movie            603535
# video            257832
# tvSeries         221817
# tvMovie          135194
# tvMiniSeries      42352
# tvSpecial         36106
# videoGame         30513
# tvShort           10484
# tvPilot               2
# Name: titleType, dtype: int64

# %% [markdown]
# The amount of items is too big, so I will keep only the movies, with more than 600k items.

# %%
basics_movies = basics.loc[basics['titleType'] == 'movie']
basics_movies
# Out:
#             tconst titleType  \
# 498      tt0000502     movie
# 570      tt0000574     movie
# 587      tt0000591     movie
# 610      tt0000615     movie
# 625      tt0000630     movie
# ...            ...       ...
# 8738140  tt9916622     movie
# 8738167  tt9916680     movie
# 8738179  tt9916706     movie
# 8738190  tt9916730     movie
# 8738200  tt9916754     movie
#
#                                               primaryTitle  \
# 498                                               Bohemios
# 570                            The Story of the Kelly Gang
# 587                                       The Prodigal Son
# 610                                     Robbery Under Arms
# 625                                                 Hamlet
# ...                                                    ...
# 8738140        Rodolpho Teóphilo - O Legado de um Pioneiro
# 8738167  De la ilusión al desconcierto: cine colombiano...
# 8738179                                    Dankyavar Danka
# 8738190                                             6 Gunn
# 8738200                     Chico Albuquerque - Revelações
#
#                                              originalTitle isAdult startYear  \
# 498                                               Bohemios       0      1905
# 570                            The Story of the Kelly Gang       0      1906
# 587                                      L'enfant prodigue       0      1907
# 610                                     Robbery Under Arms       0      1907
# 625                                                 Amleto       0      1908
# ...                                                    ...     ...       ...
# 8738140        Rodolpho Teóphilo - O Legado de um Pioneiro       0      2015
# 8738167  De la ilusión al desconcierto: cine colombiano...       0      2007
# 8738179                                    Dankyavar Danka       0      2013
# 8738190                                             6 Gunn       0      2017
# 8738200                     Chico Albuquerque - Revelações       0      2013
#
#         endYear runtimeMinutes                      genres
# 498          \N            100                          \N
# 570          \N             70  Action,Adventure,Biography
# 587          \N             90                       Drama
# 610          \N             \N                       Drama
# 625          \N             \N                       Drama
# ...         ...            ...                         ...
# 8738140      \N             57                 Documentary
# 8738167      \N            100                 Documentary
# 8738179      \N             \N                      Comedy
# 8738190      \N            116                          \N
# 8738200      \N             49                 Documentary
#
# [603535 rows x 9 columns]

# %% [markdown]
# But that is not enough, I need more information, mainly the description, and for that I will use the CinemaGoer library (https://cinemagoer.github.io):

# %%
# !pip install cinemagoer
from imdb import Cinemagoer

# create an instance of the Cinemagoer class
ia = Cinemagoer()

# get a movie
movie = ia.get_movie('0133093')

# print the genres of the movie
print('Genres:')
for genre in movie['genres']:
    print(genre)
# Out:
# Genres:
# Action
# Sci-Fi

# %%
print(ia.get_movie_infoset())
# Out:
# ['airing', 'akas', 'alternate versions', 'awards', 'connections', 'crazy credits', 'critic reviews', 'episodes', 'external reviews', 'external sites', 'faqs', 'full credits', 'goofs', 'keywords', 'list', 'locations', 'main', 'misc sites', 'news', 'official sites', 'parents guide', 'photo sites', 'plot', 'quotes', 'recommendations', 'release dates', 'release info', 'reviews', 'sound clips', 'soundtrack', 'synopsis', 'taglines', 'technical', 'trivia', 'tv schedule', 'video clips', 'vote details']

# %%
print(movie.keys())
# Out:
# ['original title', 'localized title', 'cast', 'genres', 'runtimes', 'countries', 'country codes', 'language codes', 'color info', 'aspect ratio', 'sound mix', 'box office', 'certificates', 'original air date', 'rating', 'votes', 'cover url', 'imdbID', 'plot outline', 'languages', 'title', 'year', 'kind', 'director', 'writer', 'producer', 'composer', 'cinematographer', 'editor', 'editorial department', 'casting director', 'production design', 'art direction', 'set decoration', 'costume designer', 'make up', 'production manager', 'assistant director', 'art department', 'sound crew', 'special effects', 'visual effects', 'stunt performer', 'camera and electrical department', 'animation department', 'casting department', 'costume department', 'location management', 'music department', 'script department', 'transportation department', 'miscellaneous crew', 'akas', 'top 250 rank', 'production companies', 'distributors', 'special effects companies', 'other companies', 'plot', 'synopsis', 'canonical title', 'long imdb title', 'long imdb canonical title', 'smart canonical title', 'smart long imdb canonical title', 'full-size cover url']

# %%
movie = ia.get_movie('0133093')
print(movie.data['rating'])
# Out:
# 8.7

# %%
def get_IMDB_movie_data(movie_ID=''):
    """
    Returns the following information of a title in a list form:
        IMDB rating
        genres
        MPAA rating
        Description
        maybe later: movie_title='',
    """
    # # Get movie data from IMDB API
    # ia = Cinemagoer()
    # if movie_title!='':
    #     res = ia._search_movie(movie_title, results=True)
    #     movie_ID = res[0][0]
    #     if res[0][1]['title'] != movie_title:
    #         print('Titles do not exactly match: ', movie_title, res[0][1]['title'])
    # result = pd.DataFrame()
    if movie_ID=='':
        raise Exception("No title or ID provided")
    
    movie_ID = movie_ID.replace('t', '')
    
    movie = ia.get_movie(movie_ID)
    try:
        rating = movie.data['rating']
        # result['rating'] = movie.data['rating']
    except:
        rating = pd.NA
        # result['rating'] = pd.NA

    try:
        # result['genres'] = 0
        genres = [genre.lower() for genre in movie.data['genres']]
    except:
        # result['genres'] = pd.NA
        genres = pd.NA

    try:
        # result['mpaa'] = [c.split(':')[1] for c in movie.data['certificates'] if (c.startswith('United States') or 'USA' in c)][0]
        MPAA = [c.split(':')[1] for c in movie.data['certificates'] if (c.startswith('United States') or 'USA' in c)][0]
    except:
        # result['mpaa'] = pd.NA
        MPAA = pd.NA

    try:
        # result['description'] = movie.data['plot outline']
        description = movie.data['plot outline']
    except:
        # result['description'] = pd.NA
        description = pd.NA

    try:
        # result['votes'] = movie.data['votes']
        votes = movie.data['votes']
    except:
        # result['votes'] = pd.NA
        votes = pd.NA

    # print(result)
    return (rating,genres,MPAA,description,votes)

# %%
get_IMDB_movie_data('0133093')
# Out:
# 8.7
# (8.7,
#  ['action', 'sci-fi'],
#  'R',
#  'Thomas A. Anderson is a man living two lives. By day he is an average computer programmer and by night a hacker known as Neo. Neo has always questioned his reality, but the truth is far beyond his imagination. Neo finds himself targeted by the police when he is contacted by Morpheus, a legendary computer hacker branded a terrorist by the government. As a rebel against the machines, Neo must confront the agents: super-powerful computer programs devoted to stopping Neo and the entire human rebellion.',
#  1840533)

# %%
get_IMDB_movie_data('0468569')
# Out:
# (9.1,
#  ['action', 'crime', 'drama', 'thriller'],
#  'TV-14',
#  'Set within a year after the events of Batman Begins (2005), Batman, Lieutenant James Gordon, and new District Attorney Harvey Dent successfully begin to round up the criminals that plague Gotham City, until a mysterious and sadistic criminal mastermind known only as "The Joker" appears in Gotham, creating a new wave of chaos. Batman\'s struggle against The Joker becomes deeply personal, forcing him to "confront everything he believes" and improve his technology to stop him. A love triangle develops between Bruce Wayne, Dent, and Rachel Dawes.',
#  2504092)

# %% [markdown]
# Now that it works, I will take a small sample of the movie dataset to grow the table.

# %%
movies_sample = basics_movies.sample(20, random_state=42).reset_index()
movies_sample
# Out:
#       index      tconst titleType                               primaryTitle  \
# 0    443576   tt0461760     movie                            Cut Sleeve Boys
# 1   4889474   tt1869525     movie                                Las piedras
# 2    987145  tt10034258     movie  Sergiu Celibidache: The Triumphant Return
# 3   2420451  tt12619178     movie                                     Sojiga
# 4   6556911   tt5116988     movie                              Under the Sun
# 5    267985   tt0279867     movie                                Hockey Girl
# 6   5461315   tt2599006     movie                                 Tribyville
# 7   2205273  tt12219112     movie                     Heaven Beneath My Feet
# 8   8007012   tt8332260     movie                               Anambra Boys
# 9    391498   tt0408296     movie                        Too Loud a Solitude
# 10  3172375  tt13996652     movie                             Spookie Dookie
# 11   741914   tt0765828     movie  Martin Scorsese, l'émotion par la musique
# 12  6465380   tt4910580     movie                           A Heart of Flesh
# 13  4500467   tt1664825     movie                                  Reparando
# 14   180176   tt0186976     movie                             Drop Dead Rock
# 15   361016   tt0376620     movie                              Ghar Parivaar
# 16  1047084  tt10141990     movie                       We Shall Not Die Now
# 17  6847097   tt5772358     movie                  How to Win a Tickle Fight
# 18    18427   tt0018697     movie                               The Big City
# 19    55907   tt0056987     movie                            Desant na Drvar
#
#                                 originalTitle isAdult startYear endYear  \
# 0                             Cut Sleeve Boys       0      2006      \N
# 1                                 Las piedras       0      2011      \N
# 2   Sergiu Celibidache: The Triumphant Return       0      1992      \N
# 3                                      Sojiga       0      2016      \N
# 4                               Under the Sun       0        \N      \N
# 5                                 Hockey Girl       0      2002      \N
# 6                                  Tribyville       0        \N      \N
# 7                      Heaven Beneath My Feet       0      2020      \N
# 8                                Anambra Boys       0      2018      \N
# 9                  Une trop bruyante solitude       0      1996      \N
# 10                             Spookie Dookie       0      2022      \N
# 11  Martin Scorsese, l'émotion par la musique       0      2005      \N
# 12                           A Heart of Flesh       0        \N      \N
# 13                                  Reparando       0      2010      \N
# 14                             Drop Dead Rock       0      1995      \N
# 15                              Ghar Parivaar       0      1991      \N
# 16                       We Shall Not Die Now       0      2019      \N
# 17                  How to Win a Tickle Fight       0      2016      \N
# 18                               The Big City       0      1928      \N
# 19                            Desant na Drvar       0      1963      \N
#
#    runtimeMinutes                       genres
# 0              86               Comedy,Romance
# 1              75                           \N
# 2              55                  Documentary
# 3              \N                       Action
# 4              \N    Adventure,Biography,Drama
# 5              \N                        Sport
# 6              \N                      Musical
# 7              90                  Documentary
# 8              \N                        Drama
# 9             110                 Comedy,Drama
# 10             \N                       Comedy
# 11             52                  Documentary
# 12             \N                        Drama
# 13             78  Biography,Documentary,Drama
# 14             93                       Comedy
# 15             \N                        Drama
# 16            150      Documentary,History,War
# 17             51        Adventure,Documentary
# 18             70                  Crime,Drama
# 19            105                          War

# %%
extra = movies_sample['tconst'].apply(get_IMDB_movie_data)

# %%
df = pd.DataFrame(extra.to_list(), columns=['rating','genres','mpaa','description','votes'])

# %%
df
# Out:
#    rating                                    genres       mpaa  \
# 0     6.0                         [comedy, romance]          R
# 1     6.3                                      <NA>       <NA>
# 2    <NA>                             [documentary]          G
# 3    <NA>                                  [action]       <NA>
# 4    <NA>             [adventure, biography, drama]       <NA>
# 5    <NA>                                   [sport]       <NA>
# 6    <NA>                                 [musical]       <NA>
# 7     5.6                             [documentary]       <NA>
# 8    <NA>                                   [drama]       <NA>
# 9     5.6                           [comedy, drama]       <NA>
# 10   <NA>                                  [comedy]       <NA>
# 11    6.9                             [documentary]       <NA>
# 12   <NA>                                   [drama]       <NA>
# 13    6.9  [documentary, biography, drama, history]       <NA>
# 14    5.5                                  [comedy]  Not Rated
# 15    5.4                                   [drama]       <NA>
# 16    7.8               [documentary, history, war]  Not Rated
# 17   <NA>                  [documentary, adventure]       <NA>
# 18    6.8                            [crime, drama]       <NA>
# 19    6.3                                     [war]       <NA>
#
#                                           description votes
# 0                                                <NA>   481
# 1   In a house in Delta, in a quiet interrupted on...    14
# 2                                                <NA>  <NA>
# 3                                                <NA>  <NA>
# 4                                                <NA>  <NA>
# 5                                                <NA>  <NA>
# 6                                                <NA>  <NA>
# 7   Heaven Beneath my Feet is the story of three L...     5
# 8                                                <NA>  <NA>
# 9                                                <NA>    51
# 10                                               <NA>  <NA>
# 11                                               <NA>    33
# 12                                               <NA>  <NA>
# 13  On the morning of June 18. 1954, the US CIA dr...    35
# 14  A down and out rock 'n roll band, Hindenburg, ...    68
# 15  Shankar, a country fellow, lives with his wido...    44
# 16                                               <NA>   253
# 17  A true story of one young family as they striv...  <NA>
# 18                                               <NA>    90
# 19  Raid on Drvar known as 'The Seventh Enemy Offe...   234

# %%
movies_sample_big = pd.concat([movies_sample, df], axis=1)
movies_sample_big
# Out:
#       index      tconst titleType                               primaryTitle  \
# 0    443576   tt0461760     movie                            Cut Sleeve Boys
# 1   4889474   tt1869525     movie                                Las piedras
# 2    987145  tt10034258     movie  Sergiu Celibidache: The Triumphant Return
# 3   2420451  tt12619178     movie                                     Sojiga
# 4   6556911   tt5116988     movie                              Under the Sun
# 5    267985   tt0279867     movie                                Hockey Girl
# 6   5461315   tt2599006     movie                                 Tribyville
# 7   2205273  tt12219112     movie                     Heaven Beneath My Feet
# 8   8007012   tt8332260     movie                               Anambra Boys
# 9    391498   tt0408296     movie                        Too Loud a Solitude
# 10  3172375  tt13996652     movie                             Spookie Dookie
# 11   741914   tt0765828     movie  Martin Scorsese, l'émotion par la musique
# 12  6465380   tt4910580     movie                           A Heart of Flesh
# 13  4500467   tt1664825     movie                                  Reparando
# 14   180176   tt0186976     movie                             Drop Dead Rock
# 15   361016   tt0376620     movie                              Ghar Parivaar
# 16  1047084  tt10141990     movie                       We Shall Not Die Now
# 17  6847097   tt5772358     movie                  How to Win a Tickle Fight
# 18    18427   tt0018697     movie                               The Big City
# 19    55907   tt0056987     movie                            Desant na Drvar
#
#                                 originalTitle isAdult startYear endYear  \
# 0                             Cut Sleeve Boys       0      2006      \N
# 1                                 Las piedras       0      2011      \N
# 2   Sergiu Celibidache: The Triumphant Return       0      1992      \N
# 3                                      Sojiga       0      2016      \N
# 4                               Under the Sun       0        \N      \N
# 5                                 Hockey Girl       0      2002      \N
# 6                                  Tribyville       0        \N      \N
# 7                      Heaven Beneath My Feet       0      2020      \N
# 8                                Anambra Boys       0      2018      \N
# 9                  Une trop bruyante solitude       0      1996      \N
# 10                             Spookie Dookie       0      2022      \N
# 11  Martin Scorsese, l'émotion par la musique       0      2005      \N
# 12                           A Heart of Flesh       0        \N      \N
# 13                                  Reparando       0      2010      \N
# 14                             Drop Dead Rock       0      1995      \N
# 15                              Ghar Parivaar       0      1991      \N
# 16                       We Shall Not Die Now       0      2019      \N
# 17                  How to Win a Tickle Fight       0      2016      \N
# 18                               The Big City       0      1928      \N
# 19                            Desant na Drvar       0      1963      \N
#
#    runtimeMinutes                       genres rating  \
# 0              86               Comedy,Romance    6.0
# 1              75                           \N    6.3
# 2              55                  Documentary   <NA>
# 3              \N                       Action   <NA>
# 4              \N    Adventure,Biography,Drama   <NA>
# 5              \N                        Sport   <NA>
# 6              \N                      Musical   <NA>
# 7              90                  Documentary    5.6
# 8              \N                        Drama   <NA>
# 9             110                 Comedy,Drama    5.6
# 10             \N                       Comedy   <NA>
# 11             52                  Documentary    6.9
# 12             \N                        Drama   <NA>
# 13             78  Biography,Documentary,Drama    6.9
# 14             93                       Comedy    5.5
# 15             \N                        Drama    5.4
# 16            150      Documentary,History,War    7.8
# 17             51        Adventure,Documentary   <NA>
# 18             70                  Crime,Drama    6.8
# 19            105                          War    6.3
#
#                                       genres       mpaa  \
# 0                          [comedy, romance]          R
# 1                                       <NA>       <NA>
# 2                              [documentary]          G
# 3                                   [action]       <NA>
# 4              [adventure, biography, drama]       <NA>
# 5                                    [sport]       <NA>
# 6                                  [musical]       <NA>
# 7                              [documentary]       <NA>
# 8                                    [drama]       <NA>
# 9                            [comedy, drama]       <NA>
# 10                                  [comedy]       <NA>
# 11                             [documentary]       <NA>
# 12                                   [drama]       <NA>
# 13  [documentary, biography, drama, history]       <NA>
# 14                                  [comedy]  Not Rated
# 15                                   [drama]       <NA>
# 16               [documentary, history, war]  Not Rated
# 17                  [documentary, adventure]       <NA>
# 18                            [crime, drama]       <NA>
# 19                                     [war]       <NA>
#
#                                           description votes
# 0                                                <NA>   481
# 1   In a house in Delta, in a quiet interrupted on...    14
# 2                                                <NA>  <NA>
# 3                                                <NA>  <NA>
# 4                                                <NA>  <NA>
# 5                                                <NA>  <NA>
# 6                                                <NA>  <NA>
# 7   Heaven Beneath my Feet is the story of three L...     5
# 8                                                <NA>  <NA>
# 9                                                <NA>    51
# 10                                               <NA>  <NA>
# 11                                               <NA>    33
# 12                                               <NA>  <NA>
# 13  On the morning of June 18. 1954, the US CIA dr...    35
# 14  A down and out rock 'n roll band, Hindenburg, ...    68
# 15  Shankar, a country fellow, lives with his wido...    44
# 16                                               <NA>   253
# 17  A true story of one young family as they striv...  <NA>
# 18                                               <NA>    90
# 19  Raid on Drvar known as 'The Seventh Enemy Offe...   234

# %%
# !pip install rotten-tomatoes-scraper
from rotten_tomatoes_scraper.rt_scraper import MovieScraper

# RT_search = MovieScraper()
# search_res = RT_search.search('The Big City')

# %%
def get_RT_ratings(movie_title):
    """
    Returns the Rotten Tomatoes critic score and audience score of a title
    """

    # Extract URL
    RT_search = MovieScraper()
    search_res = RT_search.search(movie_title)

    # Exact match
    url_list = [movie_dict['url'] for movie_dict in search_res['movies']
                if movie_dict['name'].lower() == movie_title.lower()]
    if len(url_list) == 1:
        url = url_list[0]
    # No exact match -  return the latest one
    elif not url_list:
        url_list = sorted([(movie_dict['url'], movie_dict['year']) for movie_dict in search_res['movies']],
                          key=lambda x: x[1], reverse=True)
        url = url_list[0][0]
        print(f'No exact match found. Going with {url}')
    # More than one exact match - return the latest one
    elif len(url_list) > 1:
        url_list = sorted([(movie_dict['url'], movie_dict['year']) for movie_dict in search_res['movies']
                           if movie_dict['name'].lower() == movie_title.lower()],
                          key=lambda x: x[1], reverse=True)
        url = url_list[0][0]
        print(f'More than one exact match found. Going with {url}')

    movie_scraper = MovieScraper(movie_url='https://www.rottentomatoes.com' + url)
    movie_scraper.extract_metadata()
    try:
        rt_critics_score = int(movie_scraper.metadata['Score_Rotten'])
    except:
        rt_critics_score = pd.NA
    rt_audience_score = int(movie_scraper.metadata['Score_Audience'])
    return rt_critics_score, rt_audience_score

# %%
get_RT_ratings('The Big City')
# Out:
# No exact match found. Going with /m/big_heart_city
# (<NA>, 0)

# %%
RT_search = MovieScraper()
search_res = RT_search.search('The Prodigal Son')
search_res
# Out:
# {'actorCount': 0,
#  'actors': [],
#  'criticCount': 0,
#  'critics': [],
#  'franchiseCount': 0,
#  'franchises': [],
#  'movieCount': 9,
#  'movies': [{'name': 'The Prodigal Son',
#    'year': 1983,
#    'url': '/m/the_prodigal_son_1983',
#    'image': 'https://resizing.flixster.com/YqA7gOe3e90cgo4iRWIeH_Ok5nE=/fit-in/80x80/v1.bTsxMjE4NjI3ODtqOzE5MDg2OzEyMDA7MjI1OzQwMA',
#    'meterClass': 'N/A',
#    'castItems': [{'name': 'Biao Yuen', 'url': '/celebrity/yuen_biao'},
#     {'name': 'Ching-Ying Lam', 'url': '/celebrity/chingying_lam'},
#     {'name': 'Sammo Kam-Bo Hung', 'url': '/celebrity/sammo_kam_bo_hung'}],
#    'subline': 'Biao Yuen, Ching-Ying Lam, Sammo Kam-Bo Hung, '},
#   {'name': 'Tuhlaajapoika (Kotikatsomo: Tuhlaajapoika) (The Prodigal Son)',
#    'year': 1992,
#    'url': '/m/tuhlaajapoika-kotikatsomo-tuhlaajapoika-the-prodigal-son',
#    'image': 'https://staticv2-4.rottentomatoes.com/static/images/redesign/poster_default_redesign.gif',
#    'meterClass': 'N/A',
#    'castItems': [{'name': 'Hannu Kivioja', 'url': '/celebrity/hannu_kivioja'},
#     {'name': 'Esko Salminen', 'url': '/celebrity/esko_salminen'},
#     {'name': 'Leena Klemola', 'url': '/celebrity/leena_klemola'}],
#    'subline': 'Hannu Kivioja, Esko Salminen, Leena Klemola, '},
#   {'name': 'Prodigal Sons',
#    'year': 2010,
#    'url': '/m/10012058-prodigal_sons',
#    'image': 'https://resizing.flixster.com/tSJUaMsyBgaNXKsPKBHk51GO0o0=/fit-in/80x80/v1.bTsxNDA4NDk3MTtqOzE5MTUzOzEyMDA7Mjg0OzQwNQ',
#    'meterClass': 'fresh',
#    'meterScore': 87,
#    'castItems': [{'name': 'Kimberly Reed', 'url': '/celebrity/770822548'},
#     {'name': 'Marc McKerrow', 'url': '/celebrity/marc_mckerrow'},
#     {'name': 'Carol McKerrow', 'url': '/celebrity/carol_mckerrow'}],
#    'subline': 'Kimberly Reed, Marc McKerrow, Carol McKerrow, '},
#   {'name': 'Choreography by Balanchine: Chaconne, Prodigal Son, Ballo della Regina, The Steadfast Tin Soldier',
#    'year': 2004,
#    'url': '/m/choreography-by-balanchine-chaconne-prodigal-son-ballo-della-regina-the-steadfast-tin-soldier',
#    'image': 'https://staticv2-4.rottentomatoes.com/static/images/redesign/poster_default_redesign.gif',
#    'meterClass': 'N/A',
#    'castItems': [{'name': 'Karin Von Aroldingen',
#      'url': '/celebrity/karin_von_aroldingen'},
#     {'name': 'Mikhail Baryshnikov', 'url': '/celebrity/mikhail_baryshnikov'},
#     {'name': 'Peter Martins', 'url': '/celebrity/peter_martins'}],
#    'subline': 'Karin Von Aroldingen, Mikhail Baryshnikov, Peter Martins, '},
#   {'name': 'Miami Vice 2 - The Prodigal Son',
#    'year': 1985,
#    'url': '/m/miami_vice_2_the_prodigal_son',
#    'image': 'https://resizing.flixster.com/AQ9to75yxFbGUBsZGJipb7fFD5I=/fit-in/80x80/v1.bTsxMjEzMzk1NztqOzE5MDg1OzEyMDA7Mjg0OzQwNQ',
#    'meterClass': 'N/A',
#    'castItems': [{'name': 'Don Johnson',
#      'url': '/celebrity/1007778-don_johnson'},
#     {'name': 'Philip Michael Thomas',
#      'url': '/celebrity/philip_michael_thomas'},
#     {'name': 'Pam Grier', 'url': '/celebrity/pam_grier'}],
#    'subline': 'Don Johnson, Philip Michael Thomas, Pam Grier, '},
#   {'name': 'The Prodigal Son',
#    'year': 2009,
#    'url': '/m/the_prodigal_son_2009',
#    'image': 'https://staticv2-4.rottentomatoes.com/static/images/redesign/poster_default_redesign.gif',
#    'meterClass': 'N/A',
#    'castItems': [],
#    'subline': ''},
#   {'name': 'Wayward: The Prodigal Son',
#    'year': 2014,
#    'url': '/m/wayward_the_prodigal_son',
#    'image': 'https://resizing.flixster.com/GTIR1ELt_VAH28n06kXkFIWR83g=/fit-in/80x80/v1.bTsxMTE4MTMxMDtqOzE5MTY0OzEyMDA7NjQ4Ozk2MA',
#    'meterClass': 'N/A',
#    'castItems': [{'name': 'Landon Henneman',
#      'url': '/celebrity/landon_henneman'},
#     {'name': 'Pam Eichner', 'url': '/celebrity/pam-eichner'},
#     {'name': 'Rob Diamond', 'url': '/celebrity/rob_diamond'}],
#    'subline': 'Landon Henneman, Pam Eichner, Rob Diamond, '},
#   {'name': 'Confessions Of A Prodigal Son',
#    'year': 2015,
#    'url': '/m/null',
#    'image': 'https://resizing.flixster.com/2X8WMV1j9P0cUopPhznTKKO2YH0=/fit-in/80x80/v1.bTsxMTE5MTU4MDtqOzE5MTY0OzEyMDA7Mjg0OzQwNQ',
#    'meterClass': 'N/A',
#    'castItems': [{'name': 'Nathan Clarkson',
#      'url': '/celebrity/nathan_clarkson'},
#     {'name': 'Kevin Sorbo', 'url': '/celebrity/kevin_sorbo'},
#     {'name': 'Rachael Lee', 'url': '/celebrity/rachael_lee'}],
#    'subline': 'Nathan Clarkson, Kevin Sorbo, Rachael Lee, '}],
#  'tvCount': 0,
#  'tvSeries': []}

# %%
import requests
from bs4 import BeautifulSoup

class IMDBScraper:
   def __init__(self, url):
       self.url = url
       self.download_page()

   def download_page(self):
       # method for downloading the hotel page
       self.page = requests.get(self.url).text

   def scrape_data(self):
       #method for scraping out movie title and description
       soup = BeautifulSoup(self.page, "html.parser")
       movie_title = soup.find("h1", {"data-testid": "hero-title-block__title"}).text
       movie_description = soup.find("span", {"data-testid": "plot-xl"}).text
       return {"title": movie_title,
               "description": movie_description,
               }

urls = ["https://www.imdb.com/title/tt2382320/?ref_=hm_fanfav_tt_i_3_pd_fp1",]

for url in urls:
   x = IMDBScraper(url)
   print(x.scrape_data())
# Out:
# {'title': 'Sin tiempo para morir', 'description': 'James Bond has left active service. His peace is short-lived when Felix Leiter, an old friend from the CIA, turns up asking for help, leading Bond onto the trail of a mysterious villain armed with dangerous new technology.'}
